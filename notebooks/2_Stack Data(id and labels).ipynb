# %%
import os
import numpy as np
from glob import glob

# conf
spectra_dir = '../data/nili_fossae_preprocessed_spectra'
labels_path = '../results/clustering/k8/labels_k8.npy'
output_dir = '../results/stacked_k8_dataset'
os.makedirs(output_dir, exist_ok=True)

# %%
# load
spectra_files = sorted(glob(os.path.join(spectra_dir, '*_spectra.npy')))
labels = np.load(labels_path)
print(f"Total labels: {len(labels):,}")
# Out:
# Total labels: 23,615,764

# %%
# stacking

offset = 0
for i, path in enumerate(spectra_files, 1):
    cube_name = os.path.basename(path).replace('_spectra.npy', '')
    spectra = np.load(path)
    if spectra.ndim > 2:
        spectra = spectra.reshape(-1, spectra.shape[-1])

    count = len(spectra)
    labels_chunk = labels[offset:offset + count]
    ids_chunk = np.array([cube_name] * count)

    np.save(os.path.join(output_dir, f'{cube_name}_X.npy'), spectra)
    np.save(os.path.join(output_dir, f'{cube_name}_y.npy'), labels_chunk)
    np.save(os.path.join(output_dir, f'{cube_name}_ids.npy'), ids_chunk)

    offset += count
    print(f"[{i}/{len(spectra_files)}] Saved {cube_name}: {count:,} pixels")

print("\n Dataset saved to disk. Load with mmap_mode='r'")
# Out:
# [1/137] Saved frt00003584_07_if166j_mtr3: 427,754 pixels
# [2/137] Saved frt000037ae_07_if166j_mtr3: 319,996 pixels
# [3/137] Saved frt00003e12_07_if166j_mtr3: 444,615 pixels
# [4/137] Saved frt00003fb9_07_if166j_mtr3: 429,990 pixels
# [5/137] Saved frt000047a3_07_if166j_mtr3: 423,865 pixels
# [6/137] Saved frt00004f75_07_if166j_mtr3: 1,824,202 pixels
# [7/137] Saved frt00005443_07_if166j_mtr3: 394,890 pixels
# [8/137] Saved frt00005850_07_if167j_mtr3: 601,925 pixels
# [9/137] Saved frt00005a3e_07_if165j_mtr3: 394,241 pixels
# [10/137] Saved frt00005c5e_07_if166j_mtr3: 460,247 pixels
# [11/137] Saved frt000064d9_07_if166j_mtr3: 442,443 pixels
# [12/137] Saved frt0000652e_07_if166j_mtr3: 396,546 pixels
# [13/137] Saved frt000066a4_07_if166j_mtr3: 269,502 pixels
# [14/137] Saved frt00007bc8_07_if166j_mtr3: 467,483 pixels
# [15/137] Saved frt0000805f_07_if166j_mtr3: 435,657 pixels
# [16/137] Saved frt00008389_07_if166j_mtr3: 380,642 pixels
# [17/137] Saved frt00008530_07_if166j_mtr3: 229,492 pixels
# [18/137] Saved frt0000857f_07_if166j_mtr3: 375,967 pixels
# [19/137] Saved frt0000871c_07_if166j_mtr3: 356,291 pixels
# [20/137] Saved frt000088d0_07_if166j_mtr3: 283,023 pixels
# [21/137] Saved frt00008fc1_07_if166j_mtr3: 289,352 pixels
# [22/137] Saved frt000091b2_07_if165j_mtr3: 329,819 pixels
# [23/137] Saved frt000093be_07_if166j_mtr3: 288,048 pixels
# [24/137] Saved frt000095fe_07_if166j_mtr3: 246,161 pixels
# [25/137] Saved frt000097e2_07_if166j_mtr3: 277,231 pixels
# [26/137] Saved frt00009971_07_if166j_mtr3: 286,107 pixels
# [27/137] Saved frt00009c31_07_if166j_mtr3: 212,648 pixels
# [28/137] Saved frt00009c6a_07_if166j_mtr3: 172,436 pixels
# [29/137] Saved frt00009d44_07_if165j_mtr3: 260,147 pixels
# [30/137] Saved frt00009d96_07_if166j_mtr3: 227,394 pixels
# [31/137] Saved frt0000a053_07_if166j_mtr3: 220,363 pixels
# [32/137] Saved frt0000a09c_07_if166j_mtr3: 239,494 pixels
# [33/137] Saved frt0000a4b5_07_if167j_mtr3: 247,912 pixels
# [34/137] Saved frt0000a4fc_07_if166j_mtr3: 275,308 pixels
# [35/137] Saved frt0000a9be_07_if165j_mtr3: 197,416 pixels
# [36/137] Saved frt0000aa03_07_if166j_mtr3: 195,109 pixels
# [37/137] Saved frt0000abcb_07_if166j_mtr3: 214,485 pixels
# [38/137] Saved frt0000b012_07_if166j_mtr3: 128,257 pixels
# [39/137] Saved frt0000b072_07_if166j_mtr3: 144,528 pixels
# [40/137] Saved frt0000b2f8_07_if165j_mtr3: 112,789 pixels
# [41/137] Saved frt0000b438_07_if166j_mtr3: 163,311 pixels
# [42/137] Saved frt0000b573_07_if166j_mtr3: 97,557 pixels
# [43/137] Saved frt0000bbcb_07_if166j_mtr3: 139,523 pixels
# [44/137] Saved frt0000bc1c_07_if166j_mtr3: 121,553 pixels
# [45/137] Saved frt0000bda8_07_if165j_mtr3: 81,401 pixels
# [46/137] Saved frt0000bec0_07_if165j_mtr3: 131,165 pixels
# [47/137] Saved frt0000beeb_07_if166j_mtr3: 197,296 pixels
# [48/137] Saved frt0000bfd1_07_if166j_mtr3: 156,969 pixels
# [49/137] Saved frt0000c202_07_if165j_mtr3: 201,990 pixels
# [50/137] Saved frt0000c256_07_if165j_mtr3: 195,008 pixels
# [51/137] Saved frt0000c5ea_07_if166j_mtr3: 198,224 pixels
# [52/137] Saved frt0000c62b_07_if166j_mtr3: 226,878 pixels
# [53/137] Saved frt0000c79d_07_if166j_mtr3: 159,798 pixels
# [54/137] Saved frt0000c968_07_if166j_mtr3: 171,121 pixels
# [55/137] Saved frt0000cbe5_07_if166j_mtr3: 147,798 pixels
# [56/137] Saved frt0000d6d6_07_if166j_mtr3: 141,886 pixels
# [57/137] Saved frt00011188_07_if166j_mtr3: 134,236 pixels
# [58/137] Saved frt0001182a_07_if165j_mtr3: 293,956 pixels
# [59/137] Saved frt00011d4c_07_if166j_mtr3: 430,661 pixels
# [60/137] Saved frt00012149_07_if166j_mtr3: 192,253 pixels
# [61/137] Saved frt000128d0_07_if165j_mtr3: 217,017 pixels
# [62/137] Saved frt00013d3b_07_if165j_mtr3: 86,138 pixels
# [63/137] Saved frt00013ebc_07_if166j_mtr3: 127,183 pixels
# [64/137] Saved frt0001487a_07_if166j_mtr3: 115,442 pixels
# [65/137] Saved frt000161ef_07_if167j_mtr3: 93,605 pixels
# [66/137] Saved frt0001642e_07_if166j_mtr3: 41,359 pixels
# [67/137] Saved frt000165f7_07_if166j_mtr3: 20,378 pixels
# [68/137] Saved frt00016655_07_if166j_mtr3: 13,050 pixels
# [69/137] Saved frt00016a73_07_if166j_mtr3: 31,303 pixels
# [70/137] Saved frt00016ed6_07_if165j_mtr3: 82,460 pixels
# [71/137] Saved frt00016f2c_07_if166j_mtr3: 100,101 pixels
# [72/137] Saved frt00017103_07_if165j_mtr3: 27,919 pixels
# [73/137] Saved frt000172dd_07_if166j_mtr3: 103,879 pixels
# [74/137] Saved frt000174f4_07_if166j_mtr3: 47,459 pixels
# [75/137] Saved frt00017736_07_if166j_mtr3: 17,036 pixels
# [76/137] Saved frt0001792c_07_if166j_mtr3: 104,453 pixels
# [77/137] Saved frt00017b1b_07_if166j_mtr3: 34,470 pixels
# [78/137] Saved frt00017d42_07_if166j_mtr3: 11,358 pixels
# [79/137] Saved frt0001821c_07_if166j_mtr3: 27,598 pixels
# [80/137] Saved frt00018524_07_if166j_mtr3: 100,869 pixels
# [81/137] Saved frt000186fa_07_if166j_mtr3: 97,790 pixels
# [82/137] Saved frt00018781_07_if165j_mtr3: 33,302 pixels
# [83/137] Saved frt00018dca_07_if166j_mtr3: 22,729 pixels
# [84/137] Saved frt00019538_07_if166j_mtr3: 40,059 pixels
# [85/137] Saved frt000199c7_07_if166j_mtr3: 80,692 pixels
# [86/137] Saved frt00019daa_07_if165j_mtr3: 68,573 pixels
# [87/137] Saved frt0001b615_07_if166j_mtr3: 189,465 pixels
# [88/137] Saved frt0001c558_07_if165j_mtr3: 88,720 pixels
# [89/137] Saved frt0001ecba_07_if166j_mtr3: 103,203 pixels
# [90/137] Saved frt0001fb74_07_if166j_mtr3: 175,266 pixels
# [91/137] Saved frt0001fd76_07_if166j_mtr3: 161,976 pixels
# [92/137] Saved frt000203de_07_if165j_mtr3: 163,778 pixels
# [93/137] Saved frt00020c77_07_if166j_mtr3: 78,947 pixels
# [94/137] Saved frt00021c5a_07_if166j_mtr3: 100,142 pixels
# [95/137] Saved frt00021da6_07_if166j_mtr3: 43,045 pixels
# [96/137] Saved frt00023370_00_if166j_mtr3: 84,027 pixels
# [97/137] Saved frt00023565_07_if166j_mtr3: 41,770 pixels
# [98/137] Saved frt00023728_07_if166j_mtr3: 41,447 pixels
# [99/137] Saved frt00024c1a_07_if165j_mtr3: 53,913 pixels
# [100/137] Saved frt000251c0_07_if165j_mtr3: 75,669 pixels
# [101/137] Saved hrl000040ff_07_if183j_mtr3: 127,925 pixels
# [102/137] Saved hrl000095a2_07_if183j_mtr3: 153,698 pixels
# [103/137] Saved hrl00009abe_07_if183j_mtr3: 101,282 pixels
# [104/137] Saved hrl0000ab0a_07_if183j_mtr3: 86,814 pixels
# [105/137] Saved hrl0000b404_07_if183j_mtr3: 75,260 pixels
# [106/137] Saved hrl0000b6ff_07_if183j_mtr3: 68,443 pixels
# [107/137] Saved hrl0000b8c2_07_if183j_mtr3: 55,389 pixels
# [108/137] Saved hrl0000bdda_07_if183j_mtr3: 50,921 pixels
# [109/137] Saved hrl0000c0ba_07_if183j_mtr3: 64,098 pixels
# [110/137] Saved hrl0000c4d8_07_if183j_mtr3: 83,718 pixels
# [111/137] Saved hrl0000cc16_07_if184j_mtr3: 122,464 pixels
# [112/137] Saved hrl0000d08f_07_if183j_mtr3: 165,568 pixels
# [113/137] Saved hrl0000d0c7_07_if183j_mtr3: 152,370 pixels
# [114/137] Saved hrl00010963_07_if183j_mtr3: 74,275 pixels
# [115/137] Saved hrl00010d72_07_if183j_mtr3: 83,983 pixels
# [116/137] Saved hrl00010eea_07_if183j_mtr3: 67,812 pixels
# [117/137] Saved hrl00011336_07_if183j_mtr3: 76,043 pixels
# [118/137] Saved hrl000116c6_07_if183j_mtr3: 118,360 pixels
# [119/137] Saved hrl00011a72_07_if183j_mtr3: 192,873 pixels
# [120/137] Saved hrl00013d8b_07_if183j_mtr3: 31,236 pixels
# [121/137] Saved hrl00013fd3_07_if183j_mtr3: 83,462 pixels
# [122/137] Saved hrl000141d5_07_if183j_mtr3: 70,534 pixels
# [123/137] Saved hrl00017fa7_07_if183j_mtr3: 34,890 pixels
# [124/137] Saved hrl0001b769_07_if183j_mtr3: 101,887 pixels
# [125/137] Saved hrl0001c7c0_07_if183j_mtr3: 60,794 pixels
# [126/137] Saved hrl0001d93d_07_if182j_mtr3: 112,556 pixels
# [127/137] Saved hrl0001d976_07_if183j_mtr3: 97,491 pixels
# [128/137] Saved hrl0001e20d_07_if183j_mtr3: 76,532 pixels
# [129/137] Saved hrl0001fc92_07_if182j_mtr3: 78,785 pixels
# [130/137] Saved hrl00020ba3_07_if183j_mtr3: 58,573 pixels
# [131/137] Saved hrl0002422e_07_if182j_mtr3: 23,342 pixels
# [132/137] Saved hrs0000b6a2_07_if176j_mtr3: 30,724 pixels
# [133/137] Saved hrs00011a2f_07_if175j_mtr3: 57,085 pixels
# [134/137] Saved hrs00011c01_07_if175j_mtr3: 57,649 pixels
# [135/137] Saved hrs00012aa7_07_if175j_mtr3: 45,132 pixels
# [136/137] Saved hrs00018c35_07_if175j_mtr3: 9,551 pixels
# [137/137] Saved hrs0001e23e_07_if175j_mtr3: 10,296 pixels
#
#  Dataset saved to disk. Load with mmap_mode='r'
